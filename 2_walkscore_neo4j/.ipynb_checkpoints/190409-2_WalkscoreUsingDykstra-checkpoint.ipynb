# %%
from IPython.display import Image
import urllib3
urllib3.disable_warnings()
# %load_ext cypher

# %% [markdown]
# # Walkscore Using Dykstra or A*
#
# The shortest distance itself doesn't always give ideal results. We can also use graph algorithms such as Dykstra or A* to compute optimal shortest distance. (see presentation from Graph Connect on this subject)[https://neo4j.com/graphconnect-2018/session/neo4j-spatial-mapping]
#
# The slide from the Graph Connect presentation illustrates the algorithms:
#
# ![190409-2_DyskstraVsA.png](attachment:190409-2_DyskstraVsA.png)
#
# ![190409-2_DykstraVsA2.png](attachment:190409-2_DykstraVsA2.png)

# %%
# %%cypher http://neo4j:password@localhost:7474/db/data
# // calculate total distance for a limited number of amenity points to the building
# match (b:Building {Code:'My Old House'})
# with b,point({ longitude: b.lon, latitude: b.lat }) as p1
#
# with b,p1
#
# // find all points of interest in boundary
# match (p2:PointOfInterest)-[]-(t:OSMTags) where distance(p1,p2.location) <= 1600 and p2.name <> 'None'
# with b,p1,collect(p2)  as pointsOfInterest
#
# unwind (pointsOfInterest) as point
#
# with b,point
#
# call algo.shortestPath.stream(b,point,{relationshipQuery:'ROUTE',nodeQuery:'Routable',direction:'BOTH',defaultValue:1.0})
# yield nodeId,cost
#
# match (n) where id(n)=nodeId
# return collect({lat:n.location.latitude,lon:n.location.longitude}) as route
# Out:
# Code [200]: OK. Request fulfilled, document follows.
#
# Neo.ClientError.Statement.SyntaxError:
# Type mismatch: expected String but was Map (line 15, column 39 (offset: 475))
# "yield nodeId,cost"
#  ^
